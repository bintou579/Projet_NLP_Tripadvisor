# %% [markdown]
# ### SPACY

# %% [markdown]
# #### Chargement corpus français

# %%
texte="L’actrice de 44 ans a donné une interview au magazine Madame Figaro. Elle y dévoile quelques détails sur les conséquences de son divorce avec son ex époux Brad Pitt. A l’occasion de la sortie deuxième volet de Maléfique, le magazine Madame Figaro a publié une interview d’Angelina Jolie, qui interprète la méchante sorcière de La Belle au bois dormant. L’actrice de 44 ans est revenue sur sa performance dans ce long-métrage signé Joachim Rønning. Mais pas que. Elle a également parlé de sa vie professionnelle, de son combat en tant qu’ambassadrice pour les Nations Unies et aussi de sa vie personnelle. «J’appréhende ma vie comme un chemin. Je suis toujours en quête de liberté, et si je peux parfois paraître audacieuse, c’est parce que je ne choisis pas vraiment la prudence ou la mesure», exprime-t-elle. Elle possède une maison «au fin fond de la jungle» et celle-ci lui a visiblement permis d’être plus courageuse. «Je travaille à l’ONU, je collabore avec des militaires, je me pousse à vivre des expériences que j’estime nécessaires à ma construction d’être humain. Je me force à faire tous les jours des choses qui m’intimident et qui parfois me font peur. Je ne me suis jamais cantonnée dans un confort physique ou émotionnel : je recherche l’épreuve du réel», poursuit la mère de six enfants. J’ai ressenti une profonde et véritable tristesse, j’étais blessée. Puis, Angelina est revenue sur son divorce en 2016 avec Brad Pitt, avec qui elle a eu trois enfants biologiques et trois enfants adoptifs : «C’était un moment compliqué, où je ne me reconnaissais plus, où j’étais devenue... comment dire... plus petite, comme insignifiante, même si cela ne se voyait pas forcément. J’ai ressenti une profonde et véritable tristesse, j’étais blessée». Bien que quatre années soit passées depuis la séparation, la relation avec l’acteur de 55 ans semble toujours très tendue. «Les circonstances de ma séparation font que j’ai dû me réinstaller à Los Angeles, car Brad veut continuer d’y vivre. L’Europe, la France, Paris, c’est une tout autre vie, ce n’est pas mon quotidien, hélas...», déplore-t-elle, avant de poursuivre : «Je préférerais voyager plus souvent, mais ce n’est pas compatible aujourd’hui avec le travail de Brad. Je coopère.». Dans l'interview, Angelina Jolie n'a cessé de rappeler qu'elle était une mère avant tout. Et elle ne le cache pas publiquement. Jeudi dernier, elle était ainsi à Tokyo pour assister à l'avant-première du nouveau film Disney. A ses côtés, deux de ses cinq enfants étaient présents. Son fils aîné Maddox (18 ans), qui a quitté depuis quelques mois déjà le foyer familial de Los Angeles pour faire ses études en Corée du Sud, en a profité pour la retrouver au Japon. L’aînée de ses filles, Zahara (14 ans), était également présente au côté de sa mère et de son frère. L'occasion de constater que l'adolescente a bien grandi et qu'elle se mue progressivement en une sublime jeune femme.".replace("’"," ")

# %%
import spacy
# Chargement du modele français
nlp = spacy.load('fr')

# %%
# Je passe mon texte en format spacy
doc = nlp(texte)

# %%
for token in doc:
    print('"' + token.text + '"')
# Out:
# "L"
# "actrice"
# "de"
# "44"
# "ans"
# "a"
# "donné"
# "une"
# "interview"
# "au"
# "magazine"
# "Madame"
# "Figaro"
# "."
# "Elle"
# "y"
# "dévoile"
# "quelques"
# "détails"
# "sur"
# "les"
# "conséquences"
# "de"
# "son"
# "divorce"
# "avec"
# "son"
# "ex"
# "époux"
# "Brad"
# "Pitt"
# "."
# "A"
# "l"
# "occasion"
# "de"
# "la"
# "sortie"
# "deuxième"
# "volet"
# "de"
# "Maléfique"
# ","
# "le"
# "magazine"
# "Madame"
# "Figaro"
# "a"
# "publié"
# "une"
# "interview"
# "d"
# "Angelina"
# "Jolie"
# ","
# "qui"
# "interprète"
# "la"
# "méchante"
# "sorcière"
# "de"
# "La"
# "Belle"
# "au"
# "bois"
# "dormant"
# "."
# "L"
# "actrice"
# "de"
# "44"
# "ans"
# "est"
# "revenue"
# "sur"
# "sa"
# "performance"
# "dans"
# "ce"
# "long"
# "-"
# "métrage"
# "signé"
# "Joachim"
# "Rønning"
# "."
# "Mais"
# "pas"
# "que"
# "."
# "Elle"
# "a"
# "également"
# "parlé"
# "de"
# "sa"
# "vie"
# "professionnelle"
# ","
# "de"
# "son"
# "combat"
# "en"
# "tant"
# "qu"
# "ambassadrice"
# "pour"
# ...

# %% [markdown]
# #### Faire apparaitre plusieurs autres prorpiétés associées à ces tokens
#
# lematize, nature (adjectif, nom, nom propre, ...), tag (genre, mode de conjugaison, ...)
#
# nb: Part-Of-Speech-Tagging (POS-Tagging)
# Le POS-Tagging consiste à associer un mot à sa classe morphosyntaxique (nom, verbe, adjectif,...).

# %%
for token in doc:
    print("{0}\t{1}\t{2}\t{3}\t{4}\t{5}\t{6}\t{7}\t{8}".format(
        token.text,
        token.idx,
        token.lemma_,
        token.is_punct,
        token.is_space,
        token.shape_,
        token.pos_,
        token.tag_,
        token.ent_type_
    ))
# Out:
# L	0	l	False	False	X	NOUN	NOUN
# actrice	2	acteur	False	False	xxxx	NOUN	NOUN__Gender=Masc|Number=Sing
# de	10	de	False	False	xx	ADP	ADP
# 44	13	44	False	False	dd	NUM	NUM__NumType=Card
# ans	16	an	False	False	xxx	NOUN	NOUN__Gender=Masc|Number=Plur
# a	20	avoir	False	False	x	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# donné	22	donner	False	False	xxxx	VERB	VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part
# une	28	un	False	False	xxx	DET	DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art
# interview	32	interview	False	False	xxxx	NOUN	NOUN__Gender=Fem|Number=Sing
# au	42	au	False	False	xx	DET	ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# magazine	45	magazine	False	False	xxxx	NOUN	NOUN__Gender=Masc|Number=Sing
# Madame	54	Monsieur	False	False	Xxxxx	NOUN	NOUN__Gender=Fem|Number=Sing	PER
# Figaro	61	Figaro	False	False	Xxxxx	PROPN	PROPN__Gender=Masc|Number=Sing	PER
# .	67	.	True	False	.	PUNCT	PUNCT
# ...

# %% [markdown]
# #### Decomposer en phrase ...

# %%
for sent in doc.sents:
    print(sent.string.strip())
    print("##########")
# Out:
# L actrice de 44 ans a donné une interview au magazine Madame Figaro.
# ##########
# Elle y dévoile quelques détails sur les conséquences de son divorce avec son ex époux Brad Pitt.
# ##########
# A l occasion de la sortie deuxième volet de Maléfique, le magazine Madame Figaro a publié une interview d Angelina Jolie, qui interprète la méchante sorcière de La Belle au bois dormant.
# ##########
# L actrice de 44 ans est revenue sur sa performance dans ce long-métrage signé Joachim Rønning.
# ##########
# Mais pas que.
# ##########
# Elle a également parlé de sa vie professionnelle, de son combat en tant qu ambassadrice pour les Nations Unies et aussi de sa vie personnelle.
# ##########
# «J appréhende ma vie comme un chemin.
# ##########
# Je suis toujours en quête de liberté, et si je peux parfois paraître audacieuse, c est parce que je ne choisis pas vraiment la prudence ou la mesure», exprime-t-elle.
# ##########
# ...

# %%
# Out:
# L actrice de 44 ans a donné une interview au magazine
# ######################
# Madame Figaro.
# ######################
# Elle y dévoile quelques détails sur les conséquences de son divorce avec son ex époux Brad Pitt.
# ######################
# A l occasion de la sortie deuxième volet de Maléfique, le magazine Madame Figaro a publié une interview d Angelina Jolie, qui interprète la méchante sorcière de La Belle au bois dormant.
# ######################
# L actrice de 44 ans est revenue sur sa performance dans ce long-métrage signé Joachim Rønning.
# ######################
# Mais pas que.
# ######################
# Elle a également parlé de sa vie professionnelle, de son combat en tant qu ambassadrice pour les Nations Unies et aussi de sa vie personnelle.
# ######################
# «J appréhende ma vie comme un chemin.
# ######################
# ...

# %% [markdown]
# #### Reconnaissance d’entités nommées / NER : Quelles entités sont déjà connues de notre modele spacy français ?
#
#
#
# SpaCy compte 17 types d’entités reconnues (en) : PERSON, NORP, FACILITY, ORG, GPE, LOC, PRODUCT, EVENT, WORK_OF_ART, LANGUAGE, DATE, TIME, PERCENT, MONEY, QUANTITY, ORDINAL et CARDINAL.

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Madame Figaro PER
# Brad Pitt PER
# Maléfique PER
# Madame Figaro PER
# Angelina Jolie PER
# La Belle au bois dormant MISC
# Joachim Rønning PER
# Nations Unies ORG
# J appréhende ma vie MISC
# c MISC
# » MISC
# » MISC
# ONU ORG
# » MISC
# Angelina MISC
# Brad Pitt PER
# C MISC
# » ORG
# Les circonstances de ma séparation MISC
# Los Angeles LOC
# Brad PER
# Europe LOC
# France LOC
# Paris LOC
# Brad PER
# Angelina Jolie PER
# Tokyo LOC
# Disney ORG
# Maddox PER
# Los Angeles LOC
# Corée du Sud LOC
# Japon LOC
# Zahara PER

# %%
# Out:
# Madame Figaro PER
# Brad Pitt PER
# Maléfique LOC
# Madame Figaro ORG
# Angelina Jolie PER
# La Belle au bois MISC
# Joachim Rønning PER
# Nations Unies ORG
# J appréhende ma vie MISC
# l ONU ORG
# Angelina PER
# Brad Pitt PER
# C MISC
# Los Angeles LOC
# Brad PER
# Europe LOC
# France LOC
# Paris LOC
# Brad PER
# Angelina Jolie PER
# Jeudi PER
# Tokyo LOC
# Disney MISC
# Maddox PER
# Corée du Sud LOC
# Japon LOC
# Zahara PER

# %% [markdown]
# #### Petite viz sympa pour les voir

# %%
from spacy import displacy
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">L actrice de 44 ans a donné une interview au magazine
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madame Figaro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . Elle y dévoile quelques détails sur les conséquences de son divorce avec son ex époux
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brad Pitt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . A l occasion de la sortie deuxième volet de
# ...

# %% [markdown]
# ####  Observer les dépendances entre les mots

# %%
for token in doc:
    print("{0}/{1} <--{2}-- {3}/{4}".format(
                                    token.text,
                                    token.tag_,
                                    token.dep_,
                                    token.head.text,
                                    token.head.tag_))
    print("##########")
# Out:
# L/NOUN <--det-- actrice/NOUN__Gender=Masc|Number=Sing
# ##########
# actrice/NOUN__Gender=Masc|Number=Sing <--nsubj-- donné/VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part
# ##########
# de/ADP <--case-- ans/NOUN__Gender=Masc|Number=Plur
# ##########
# 44/NUM__NumType=Card <--nummod-- ans/NOUN__Gender=Masc|Number=Plur
# ##########
# ans/NOUN__Gender=Masc|Number=Plur <--nmod-- actrice/NOUN__Gender=Masc|Number=Sing
# ##########
# a/AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin <--aux:tense-- donné/VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part
# ##########
# donné/VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part <--ROOT-- donné/VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part
# ##########
# une/DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art <--det-- interview/NOUN__Gender=Fem|Number=Sing
# ##########
# interview/NOUN__Gender=Fem|Number=Sing <--obj-- donné/VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part
# ##########
# ...

# %%
for sent in doc.sents:
    print(sent.string.strip())
    displacy.serve(sent, style="dep")
    print("#######")
# Out:
# L actrice de 44 ans a donné une interview au magazine Madame Figaro.
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="fr">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="37e4ca4fd6aa4cc99abad8b1296563e7-0" class="displacy" width="2325" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">L</tspan>
# ...

# %%
# avec displacy
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="ecb79ab84f834d29a617aa9134b63d98-0" class="displacy" width="91575" height="1799.5" direction="ltr" style="max-width: none; height: 1799.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">L</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">actrice</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">de</tspan>
# ...

# %% [markdown]
# #### Un peu de Word embedding
#
#  importez le modele prenetrainé en français

# %%
# !python -m spacy download fr_core_news_md
# Out:
# ...
#   Created wheel for fr-core-news-md: filename=fr_core_news_md-2.3.0-py3-none-any.whl size=46100672 sha256=5b55c3db0a896b5bfc560078daf6356c57d8309318dbdf8a25bf4d11addc1c60
#   Stored in directory: C:\Users\choco\AppData\Local\Temp\pip-ephem-wheel-cache-s_c6bvdc\wheels\62\a5\93\9c82d8ae84430ed80720262c11726d046d3444af301b7d2895
# Successfully built fr-core-news-md
# ...
# [+] Download and installation successful
# You can now load the model via spacy.load('fr_core_news_md')

# %%
import spacy
import fr_core_news_md
nlp = spacy.load("fr_core_news_md")

# %%
print(nlp.vocab['homme'].vector)
# Out:
# [ 1.3794    -3.0877    -2.8388     4.7016    -0.1659     0.14781
#   0.033792   0.26509    1.4526    -1.4321    -0.91313   -1.0259
#   1.2647    -0.79609   -0.049972  -1.5248    -0.17774   -1.0661
#   0.084368   0.36584   -0.064651   4.0417     1.1905    -0.80253
#   1.6038    -3.4513    -2.2716    -1.6903    -0.6076     0.71016
#   3.6754    -3.0272    -3.8246     0.30627    0.26215   -0.30547
#  -0.60099    2.2127    -1.4185    -0.63633   -1.7011    -1.454
#  -0.47866    2.5882     0.37455   -0.85314    1.5105     0.63346
#  -2.3088    -1.0413     1.0978    -1.3121    -3.8465     2.1385
#  -0.1453    -0.67449   -0.69743   -0.90591   -1.2146    -0.086382
#   0.26876   -3.0823    -0.19211   -0.15652    2.1992    -0.47988
#   0.79581   -0.40177   -1.7259     1.3797     3.1203     0.60337
#  -1.2963    -1.9209    -1.5247     0.42735   -2.6219    -1.7985
#  -0.38989    2.4905    -5.4963     1.2926    -0.56484    3.347
#  -2.4554     3.1172     0.66259   -1.1192     0.1707     2.5778
# ...

# %% [markdown]
# #### Quelle est la dimension de l'espace dans lequel sont projetés les mots ?

# %% [markdown]
# #### Faite une petite operation vectorielle du type :
#
# charette - cheval + moteur= ?
#
# avion - moteur + animal = ?

# %%
import numpy as np

# %%
nlp('charette').vector
# Out:
# array([ 0.049492, -1.0746  , -1.2159  ,  1.3052  , -1.8261  ,  4.2083  ,
#         0.28241 , -1.3761  , -2.0777  , -1.3182  ,  0.35681 , -1.4587  ,
#         1.7383  , -2.0597  ,  0.20741 ,  0.77469 ,  0.67236 ,  0.13478 ,
#         2.482   , -1.2193  , -3.5359  ,  2.8436  , -0.13125 , -0.012738,
#        -2.4988  , -1.128   , -0.95545 , -0.58018 , -0.30259 ,  1.203   ,
#         1.9442  , -1.269   , -0.30608 , -0.011728,  1.0466  ,  0.53639 ,
#         0.24317 , -1.4176  , -2.547   , -0.16695 ,  0.75104 , -1.1672  ,
#         0.93404 ,  1.5787  ,  2.3519  ,  2.2089  , -1.4987  ,  1.8753  ,
#        -1.2305  ,  1.158   ,  0.60554 , -0.99391 , -1.2655  ,  1.8779  ,
#         0.20587 ,  0.16566 ,  2.293   , -0.5642  , -2.1016  , -3.4375  ,
#         1.2794  , -1.5446  , -0.31772 ,  0.70586 ,  0.22652 ,  0.57494 ,
#        -0.81966 , -1.1222  , -1.8042  , -0.13465 , -0.90944 , -1.8763  ,
#         1.3263  , -2.1517  , -0.68385 ,  0.60033 , -4.0279  ,  0.37704 ,
# ...

# %%
doc = nlp('homme').vector + nlp('reine').vector - nlp('femme').vector

# %%
doc_test = doc.reshape(1,300)

# %%
doc.shape
# Out:
# (300,)

# %%
doc_test.shape
# Out:
# (1, 300)

# %%
most_similar = nlp.vocab.vectors.most_similar(doc_test, n=10)

# %%
most_similar
# Out:
# (array([[ 8650487160195411452,  3432475118910769844, 12228836950571089385,
#          15288960735970362250, 10047784810176745541, 14499379316245738847,
#           4350930411643201542,   865141709624343011, 17392124893710243702,
#           2721215222424664365]], dtype=uint64),
#  array([[ 3364, 19771,   817,  7070, 10091,  2675,  7509,  3294,  6967,
#           3769]], dtype=int32),
#  array([[0.6595, 0.6461, 0.6339, 0.6146, 0.6103, 0.6037, 0.5763, 0.5737,
#          0.5538, 0.5487]], dtype=float32))

# %%
most_similar[0].shape
# Out:
# (1, 10)

# %%
for i in range(most_similar[0].shape[1]):
    print(most_similar[0][0][i], nlp.vocab.strings[most_similar[0][0][i]])
# Out:
# 8650487160195411452 vice-reine
# 3432475118910769844 Énarque
# 12228836950571089385 Sigtrygg
# 15288960735970362250 E-81
# 10047784810176745541 ereur
# 14499379316245738847 vice-prince
# 4350930411643201542 Salvhane
# 865141709624343011 Curopalate
# 17392124893710243702 Azato
# 2721215222424664365 Ballithar

# %%
queries = np.asarray([np.random.uniform(-1, 1, (300,))])

# %%
queries.shape
# Out:
# (1, 300)

# %%
nlp("charette").similarity(nlp("cheval"))
# Out:
# 0.3938625291684884

# %%
from scipy.spatial import distance

ids = [x for x in nlp.vocab.vectors.keys()]
vectors = [nlp.vocab.vectors[x] for x in ids]
vectors = np.array(vectors)


closest_index = distance.cdist(doc_test, vectors).argmin()

word_id = ids[closest_index]
output_word = nlp.vocab[word_id].text

print(output_word)
# Out:
# monarque

# %%
# Out:
# ['orbiteurs', 'Survol', 'géostationnaire', 'atterrisseur', 'Destination', 'Spatial', 'lock‐outer', 'rovers', 'soucoupe', 'sonde']

# %% [markdown]
# #### Verifiez la cohérence de ce model
#
# calculez le rapprochement sémantique de mots parfaitement independants, puis trouver d'autres mots qui permettraient de reduire ces ecarts
#
# exemple :
# - grand / petit
# - moyen / normal
# - tres / trop

# %%
nlp("petit").similarity(nlp("moyen"))
# Out:
# 0.16050354994176375

# %%
theme=['economie', 'politique','sport','musique','santé','loisir','voyage']

text1 = "Le gouvernement annonce son «plan jeunes» à 6,5 milliards d’euros, «du jamais vu» selon Jean Castex"

for text2 in theme:
    doc1 = nlp(text1)
    doc2 = nlp(text2)
    print(text2)
    print("spaCy :", doc1.similarity(doc2))
    print("##################")
# Out:
# economie
# spaCy : 0.33707755083784563
# ##################
# politique
# spaCy : 0.49919291836958685
# ##################
# sport
# spaCy : 0.0813882878016658
# ##################
# musique
# spaCy : 0.19202501034990307
# ##################
# santé
# spaCy : 0.20021270091554408
# ##################
# loisir
# spaCy : 0.09121686613193603
# ##################
# voyage
# spaCy : 0.07427876057347838
# ##################

# %% [markdown]
# nb:Si c'est pas terrible, utilisez un model gensim préentrainé (vous pouvez prendre un des miens sur le drive) et réaliser ces opérations de mesure de distance sémantique.

# %% [markdown]
# #### Prenez un corpus de news (une dizaine sera suffisant), le but de cette application est de ranger/labelliser ces news dans un des themes predifinis suivants theme=['economie','sport','musique','santé','loisir','voyage']
#
# - Apres avoir nettoyer intelligemment votre texte
# - Apres avoir retirer certaines categories de mots (les VERBES, nom propre, ....) via spacy (par ex)
# - Trouver un moyen de classer ces news (utiliser par exemple la methode de calcul de distance semantique
# entre deux mots
# - Réaliser une dataviz type radar/spider permettant de qualifier ces news visuellement

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# Import Dataset
df = pd.read_json('https://raw.githubusercontent.com/selva86/datasets/master/newsgroups.json')
print(df.target_names.unique())
df.head()

# Convert to list
data = df.content.values.tolist()

# Remove Emails
data = [re.sub('\S*@\S*\s?', '', sent) for sent in data]

# Remove new line characters
data = [re.sub('\s+', ' ', sent) for sent in data]

# Remove distracting single quotes
data = [re.sub("\'", "", sent) for sent in data]

pprint(data[:1])

def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

print(data_words[:1])
# Out:
# ['rec.autos' 'comp.sys.mac.hardware' 'comp.graphics' 'sci.space'
#  'talk.politics.guns' 'sci.med' 'comp.sys.ibm.pc.hardware'
#  'comp.os.ms-windows.misc' 'rec.motorcycles' 'talk.religion.misc'
#  'misc.forsale' 'alt.atheism' 'sci.electronics' 'comp.windows.x'
#  'rec.sport.hockey' 'rec.sport.baseball' 'soc.religion.christian'
#  'talk.politics.mideast' 'talk.politics.misc' 'sci.crypt']
# ['From: (wheres my thing) Subject: WHAT car is this!? Nntp-Posting-Host: '
#  'rac3.wam.umd.edu Organization: University of Maryland, College Park Lines: '
#  '15 I was wondering if anyone out there could enlighten me on this car I saw '
#  'the other day. It was a 2-door sports car, looked to be from the late 60s/ '
#  'early 70s. It was called a Bricklin. The doors were really small. In '
#  'addition, the front bumper was separate from the rest of the body. This is '
#  'all I know. If anyone can tellme a model name, engine specs, years of '
# ...

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['from', 'wheres', 'my', 'thing', 'subject', 'what', 'car', 'is', 'this', 'nntp_posting_host', 'rac_wam_umd_edu', 'organization', 'university', 'of', 'maryland_college_park', 'lines', 'was', 'wondering', 'if', 'anyone', 'out', 'there', 'could', 'enlighten', 'me', 'on', 'this', 'car', 'saw', 'the', 'other', 'day', 'it', 'was', 'door', 'sports', 'car', 'looked', 'to', 'be', 'from', 'the', 'late', 'early', 'it', 'was', 'called', 'bricklin', 'the', 'doors', 'were', 'really', 'small', 'in', 'addition', 'the', 'front_bumper', 'was', 'separate', 'from', 'the', 'rest', 'of', 'the', 'body', 'this', 'is', 'all', 'know', 'if', 'anyone', 'can', 'tellme', 'model', 'name', 'engine', 'specs', 'years', 'of', 'production', 'where', 'this', 'car', 'is', 'made', 'history', 'or', 'whatever', 'info', 'you', 'have', 'on', 'this', 'funky', 'looking', 'car', 'please', 'mail', 'thanks', 'il', 'brought', 'to', 'you', 'by', 'your', 'neighborhood', 'lerxst']

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

print(data_lemmatized[:1])
# Out:
# [['where', 'thing', 'car', 'nntp_poste', 'host', 'park', 'line', 'wonder', 'could', 'enlighten', 'car', 'see', 'day', 'door', 'sport', 'car', 'look', 'late', 'early', 'call', 'door', 'really', 'small', 'addition', 'separate', 'rest', 'body', 'know', 'model', 'name', 'engine', 'spec', 'year', 'production', 'car', 'make', 'history', 'info', 'funky', 'look', 'car', 'mail', 'thank', 'bring', 'neighborhood', 'lerxst']]

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# %%
id2word

# %%
# Create Corpus
texts = data_lemmatized

# %%
texts
# Out:
# [['where',
#   'thing',
#   'car',
#   'nntp_poste',
#   'host',
#   'park',
#   'line',
#   'wonder',
#   'could',
#   'enlighten',
#   'car',
#   'see',
#   'day',
#   'door',
#   'sport',
#   'car',
#   'look',
#   'late',
#   'early',
#   'call',
#   'door',
#   'really',
#   'small',
#   'addition',
#   'separate',
#   'rest',
#   'body',
#   'know',
#   'model',
#   'name',
#   'engine',
#   'spec',
#   'year',
#   'production',
#   'car',
#   'make',
#   'history',
#   'info',
#   'funky',
#   'look',
#   'car',
#   'mail',
#   'thank',
#   'bring',
#   'neighborhood',
#   'lerxst'],
#  ['si',
#   'poll',
#   'final',
#   'summary',
#   'final',
#   'call',
#   'si',
#   'clock',
#   'report',
#   'keyword',
#   'si',
#   'acceleration',
#   'clock',
#   'line',
#   'host',
#   'fair',
#   'number',
#   'brave',
#   'soul',
#   'upgrade',
#   'clock',
#   'oscillator',
#   'share',
#   'experience',
#   'poll',
#   'send',
#   'brief',
#   'message',
#   'detail',
# ...

# %%
final_list = []

for text in texts:
    new_text = ' '.join(text)
    final_list.append(new_text)

# %%
len(final_list)
# Out:
# 11314

# %%
# !python -m spacy download en_core_web_md
# Out:
# ...
#   Created wheel for en-core-web-md: filename=en_core_web_md-2.3.1-py3-none-any.whl size=50916646 sha256=b4f72a4c122f80963f94e62b739fb1f78b1dff52ad9de5e3b938ccf34ad9d415
#   Stored in directory: C:\Users\choco\AppData\Local\Temp\pip-ephem-wheel-cache-q92apylf\wheels\43\1d\c1\a0af68d0648debf57f875e9dda56bbac35cfc27bfa187ffc46
# Successfully built en-core-web-md
# ...
# [+] Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')

# %%
import en_core_web_md

nlp = en_core_web_md.load()

# %%
import time
from random import sample

# %%
test_list = sample(final_list,100)

# %%
len(test_list)
# Out:
# 100

# %%
score = []
theme=['economy','sport','music','health','leisure', 'tech','travel']
for i in range(len(test_list)):
    score_text = []
    for text2 in theme:
        doc1 = nlp(test_list[i])
        doc2 = nlp(text2)
#         print(text2)
        score_text.append(doc1.similarity(doc2))
    score.append(score_text)
#         print("##################")

# %%
df = pd.DataFrame(columns=theme)

# %%
for i in range(len(score)):
    df.loc[len(df)] = score[i]

# %%
df
# Out:
#      economy     sport     music    health   leisure      tech    travel
# 0   0.445369  0.484821  0.416874  0.493401  0.329412  0.407599  0.453747
# 1   0.401188  0.422410  0.423594  0.459853  0.325103  0.396341  0.426573
# 2   0.387796  0.368190  0.396468  0.463494  0.272976  0.297912  0.384490
# 3   0.369978  0.404324  0.429331  0.413496  0.299308  0.333012  0.442692
# 4   0.430884  0.396190  0.415441  0.472641  0.274846  0.344473  0.361945
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.378160  0.364658  0.396159  0.413423  0.306910  0.399607  0.420070
# 96  0.304103  0.294981  0.406597  0.449786  0.293799  0.375630  0.382580
# 97  0.346534  0.332120  0.398183  0.484275  0.266763  0.345752  0.405286
# 98  0.392839  0.394864  0.442042  0.461931  0.345258  0.511952  0.391454
# 99  0.423894  0.365775  0.417377  0.492075  0.280407  0.362490  0.397412
#
# [100 rows x 7 columns]

# %%
score
# Out:
# [[0.4318692829302666,
#   0.43613785955000994,
#   0.5168743421459917,
#   0.4550270778603627,
#   0.3770346517377326,
#   0.4312291145981754,
#   0.4785676697987135],
#  [0.43608033584615513,
#   0.4344504475444297,
#   0.5312866512613084,
#   0.41274330682943977,
#   0.4367464561499077,
#   0.3958863457744152,
#   0.49681383354077274],
#  [0.48584030745548007,
#   0.43314150254725825,
#   0.5448031224558993,
#   0.38529351621839775,
#   0.43405582931966336,
#   0.3884957888583729,
#   0.5010032885900806],
#  [0.4592359649516025,
#   0.42067624007262805,
#   0.5491588162031166,
#   0.41202409901326853,
#   0.4556761677514753,
#   0.4138843726173044,
#   0.512175928376652],
#  [0.48084892167643045,
#   0.4087800789087896,
#   0.551246797620824,
#   0.3726090507518566,
#   0.4492606437211703,
#   0.362678998844108,
#   0.4422117355408057],
#  [0.5261835585548238,
#   0.47895683471275197,
#   0.5916043124003171,
#   0.442302727518574,
#   0.43908110636210435,
#   0.4780181472208404,
# ...

# %%
def plot_radar(idx):
    # categories
    categories = df.iloc[idx,:].index.tolist()
    N = len(categories) # get number of categories
    
    # values
    values= df.iloc[idx,:].values.tolist()
    values += values[:1] # repeat first value to close poly
    # calculate angle for each category
    angles = [n / float(N) * 2 * np.pi for n in range(N)]
    angles += angles[:1] # repeat first angle to close poly
    # plot
    plt.polar(angles, values, marker='.') # lines
    plt.fill(angles, values, alpha=0.3) # area
    
    # xticks
    plt.xticks(angles[:-1], categories)
    # yticks
    ax.set_rlabel_position(0) # yticks position
    plt.yticks([0.2, 0.4, 0.6, 0.8, 1], color="grey", size=10)
    plt.ylim(0,0.7)

# %%
fig = plt.figure(figsize=(12,8))
# radar 1
ax = plt.subplot(121, polar="True")
plot_radar(0)
# radar 2
ax = plt.subplot(122, polar="True")
plot_radar(58)
plt.show()
